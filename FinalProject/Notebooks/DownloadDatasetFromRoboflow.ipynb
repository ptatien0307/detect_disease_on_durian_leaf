# %%
# !pip install roboflow

# %%
from roboflow import Roboflow

# %% [markdown]
# # YOLOv4

# %% [markdown]
# ## Test

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("testdurianleaf")
dataset = project.version(1).download("darknet", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData in darknet:: 100%|██████████| 204/204 [00:06<00:00, 32.01it/s]

# %% [markdown]
# ## Validation

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("valdurianleaf")
dataset = project.version(1).download("darknet", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData in darknet:: 100%|██████████| 104/104 [00:03<00:00, 26.12it/s]

# %% [markdown]
# ## Train

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("traindurianleaf")
dataset = project.version(2).download("darknet", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet/MyData in darknet:: 100%|██████████| 3004/3004 [01:09<00:00, 43.43it/s]

# %% [markdown]
# # YOLOv5

# %% [markdown]
# ## Test

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("testdurianleaf")
dataset = project.version(1).download("yolov5", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData in yolov5pytorch:: 100%|██████████| 206/206 [00:07<00:00, 28.64it/s]

# %% [markdown]
# ## Validation

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("valdurianleaf")
dataset = project.version(1).download("yolov5", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData in yolov5pytorch:: 100%|██████████| 106/106 [00:03<00:00, 33.23it/s]

# %% [markdown]
# ## Train

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("traindurianleaf")
dataset = project.version(2).download("yolov5", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5/MyData in yolov5pytorch:: 100%|██████████| 3006/3006 [01:06<00:00, 45.45it/s]

# %% [markdown]
# # Faster R-CNN

# %% [markdown]
# ## Test

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("testdurianleaf")
dataset = project.version(1).download("coco", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData in coco:: 100%|██████████| 104/104 [00:05<00:00, 18.52it/s]

# %% [markdown]
# ## Validation

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("valdurianleaf")
dataset = project.version(1).download("coco", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData in coco:: 100%|██████████| 54/54 [00:01<00:00, 27.96it/s]

# %% [markdown]
# ## Train

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("traindurianleaf")
dataset = project.version(2).download("coco", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData in coco:: 100%|██████████| 1504/1504 [00:37<00:00, 39.59it/s]

# %% [markdown]
# # Bonus

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("aug-g73qf")
dataset = project.version(3).download("yolov5", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/yolov5 in yolov5pytorch:: 100%|██████████| 906/906 [00:22<00:00, 39.85it/s]

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("aug-g73qf")
dataset = project.version(3).download("coco", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN in coco:: 100%|██████████| 454/454 [00:11<00:00, 38.44it/s]

# %%
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("aug-g73qf")
dataset = project.version(3).download("darknet", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/darknet in darknet:: 100%|██████████| 904/904 [00:20<00:00, 44.29it/s]

# %%
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 145 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 178 kB 50.5 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 41.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 57.9 MB/s
# ...
#      |████████████████████████████████| 21.8 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 138 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 53.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.7-py3-none-any.whl size=24049 sha256=fddd2a7433b4b65208ec40f023b33bcdb6bbd5520dce9688ac35cbdbc451378e
#   Stored in directory: /root/.cache/pip/wheels/e6/e3/d6/a142059abb9cc856d3c499a9f6f354d6bcd34ba971addce12b
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("train-cpojg")
dataset = project.version(2).download("darknet", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv4/MyData in darknet:: 100%|██████████| 398/398 [00:12<00:00, 30.84it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("train-cpojg")
dataset = project.version(2).download("yolov5", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/YOLOv5/MyData in yolov5pytorch:: 100%|██████████| 400/400 [00:13<00:00, 30.12it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lBxwDsJSwYXXpQewuBS2")
project = rf.workspace("ptatien-lomkd").project("train-cpojg")
dataset = project.version(2).download("coco", location='/content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/CS114.M21.KHCL/DoAn/Model/Faster R-CNN/MyData in coco:: 100%|██████████| 201/201 [00:07<00:00, 25.79it/s]
